# %%
# Infrastructure and Economic Activity Clustering

Exploratory analysis using infrastructure accessibility and
industrial–commercial activity data.

# %%
import pandas as pd

# %%
df1 = pd.read_csv("data/file1.csv")
df1.head()

# %%
df2 = pd.read_csv("data/file2.csv")
df2.head()

# %%
## Notes

This notebook loads and inspects infrastructure and economic
activity datasets for further exploratory analysis.

The project focuses on structure, reproducibility, and interpretation.
